# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread('C:\\Users\\User\\Desktop\\apresentação python\\imagem3.jpg')
print("""A experimento da fenda dupla é um classico da fisica quantica\n
a seguir realizaremos um exemplo do que um fisico veria ao realizado
de acordo com o seguinte caso""")
plt.imshow(img)
# Out:
# A experimento da fenda dupla é um classico da fisica quantica
#
# a seguir realizaremos um exemplo do que um fisico veria ao realizado
# de acordo com o seguinte caso

# %%
#verificar se há equipamento para o teste
canhao = str(input('você tem um canhão que dispara um eletron de cada vez? [S/N]: ')).strip().upper()
if canhao not in 'Ss':
    print('Impossivel continuar com o experimento')
fenda = str(input('possui uma chapa com dupla fenda? [S/N]: ')).strip().upper()
if fenda not in 'Ss':
    print('Impossivel continuar com o experimento')
# Out:
# você tem um canhão que dispara um eletron de cada vez? [S/N]: s
# possui uma chapa com dupla fenda? [S/N]: s

# %%
# Determinando qual situação será aplicada no experimento
situacao = int(input("""escolha a opção para definir qual situação será excutada no experimento
1 - não existe observador
2 - observador antes da fenda dupla
3 - observador depois da fenda dupla
opção: """))
while situacao != 1 and situacao != 2 and situacao != 3:
    print('opção invalida')
    situacao = int(input("""escolha a opção para definir qual situação será excutada no experimento
        1 - não existe observador
        2 - observador antes da fenda dupla
        3 - observador depois da fenda dupla
        opção: """))
print('-='*30)
print('eletrons disparados')
print('-=' * 30)
# Out:
# escolha a opção para definir qual situação será excutada no experimento
# 1 - não existe observador
# 2 - observador antes da fenda dupla
# 3 - observador depois da fenda dupla
# opção: 3
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# eletrons disparados
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=

# %%
# Sequência de possibilidades de acordo com a opção marcada anteriormente
if situacao ==1:
    img = plt.imread('C:\\Users\\User\\Desktop\\apresentação python\\fig-4.jpg')
    plt.imshow(img)
    print('- Enigma quantico: Eletron aparece nas duas fendas simultaneamente\n'
          'objeto ocupando duas posições simultaneamente\n'
          'padrão de onda\n'
          'você observa varias marcas na parede, a do meio é mais forte (intensa)\n')
    print(' - Maior enima da Física nos ultimos 100 anos(ou um dos maiores)\n'
          'Einstein não conseguia explicar --> "Fantasmagórico"/Bizarro - Falou\n')
elif situacao == 2:
    img = plt.imread('C:\\Users\\User\\Desktop\\apresentação python\\fig-2.jpg')
    plt.imshow(img)
    print('eletron se comporta como partícula, perfeitamente explicavel\n'
          'duas marcas na parede final\n'
          'numa partícula maior se espera esse padrão sempre\n'
          'respeita a logica, não pode estar em dois lugares ao mesmo tempo\n'
          'não pode voltar no tempo\n')
elif situacao == 3:
    img = plt.imread('C:\\Users\\User\\Desktop\\apresentação python\\fig-4.jpg')
    plt.imshow(img)
    print('-Enigma Quântico: Elétron(particula), nas duas fendas simultaneamente\n'
          'objeto ocupando duas posições simultaneamente\n'
          '-Elétron volta no tempo e se comporta como partícula:\n'
          '    - passa somente por uma fenda\n'
          '    - Incrível voltar no tempo - enigma Quântico\n'
          '    - Ligação entre fisica e consciência\n')
    print(' - Maior enima da Física nos ultimos 100 anos(ou um dos maiores)\n'
          'Einstein não conseguia explicar --> "Fantasmagórico"/Bizarro -  Falou\n')
# Out:
# -Enigma Quântico: Elétron(particula), nas duas fendas simultaneamente
# objeto ocupando duas posições simultaneamente
# -Elétron volta no tempo e se comporta como partícula:
#     - passa somente por uma fenda
#     - Incrível voltar no tempo - enigma Quântico
#     - Ligação entre fisica e consciência
#
#  - Maior enima da Física nos ultimos 100 anos(ou um dos maiores)
# Einstein não conseguia explicar --> "Fantasmagórico"/Bizarro -  Falou
