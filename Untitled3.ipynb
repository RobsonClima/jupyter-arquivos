# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats
from statsmodels.formula.api import ols
import numpy as np

# %%
dados = pd.read_excel('C:\\Users\\User\\Desktop\\projeto Matheus\\h1.xlsx')
dados.head()
# Out:
#          Grupo  Quantos anos você tem?  p_compart  p_coment  p_curtem  \
# 0  Centennials                      18          5         6         7
# 1  Centennials                      18          7         7         7
# 2  Centennials                      18          6         6         7
# 3  Centennials                      18          6         6         7
# 4  Centennials                      18          5         4         6
#
#    prox_marc  int_compr
# 0          7          7
# 1          7          7
# 2          5          7
# 3          5          7
# 4          6          7

# %%
dados1 = dados.loc[dados['Grupo'] == 'genx']
dados1.head()
# Out:
#     Grupo  Quantos anos você tem?  p_compart  p_coment  p_curtem  prox_marc  \
# 358  genx                      26          6         6         5          5
# 359  genx                      26          4         4         5          2
# 360  genx                      26          4         4         5          2
# 361  genx                      26          7         7         7          7
# 362  genx                      26          5         6         6          6
#
#      int_compr
# 358          5
# 359          6
# 360          6
# 361          7
# 362          7

# %%
dados_melt = dados[:]
dados_melt=pd.melt(dados_melt.reset_index(), id_vars=['Grupo'], value_vars=['p_compart','p_coment','p_curtem','prox_marc','int_compr'])

# %%
x = dados_melt[1][1:356]
y = dados_melt[1][357:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6664010f0a6d> in <module>
# ----> 1 x = dados_melt[1][1:356]
#       2 y = dados_melt[1][357:]
#
# NameError: name 'dados_melt' is not defined

# %%
stats.kruskal(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#
# TypeError: '<' not supported between instances of 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-c7a2647e894b> in <module>
# ----> 1 stats.kruskal(x, y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in kruskal(*args, **kwargs)
#    7211
#    7212     alldata = np.concatenate(args)
# -> 7213     ranked = rankdata(alldata)
#    7214     ties = tiecorrect(ranked)
#    7215     if ties == 0:
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


from sklearn import decomposition
from sklearn import datasets

np.random.seed(5)

centers = [[1, 1], [-1, -1], [1, -1]]
iris = datasets.load_iris()
X = iris.data
y = iris.target

fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

plt.cla()
pca = decomposition.PCA(n_components=3)
pca.fit(X)
X = pca.transform(X)

for name, label in [('Setosa', 0), ('Versicolour', 1), ('Virginica', 2)]:
    ax.text3D(X[y == label, 0].mean(),
              X[y == label, 1].mean() + 1.5,
              X[y == label, 2].mean(), name,
              horizontalalignment='center',
              bbox=dict(alpha=.5, edgecolor='w', facecolor='w'))
# Reorder the labels to have colors matching the cluster results
y = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral,
           edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])

plt.show()
